# %% [markdown]
# <a href="https://colab.research.google.com/github/Benqui/facial-recognition-on-keras/blob/main/prometeus/pf_reconocimiento_facial_mark02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link de la base de datos datosa https://drive.google.com/drive/folders/11kV3rkFNFevtIhE8Id1c5rcv1L5onkVz?usp=sharing

# %%
# !pip install brewer2mpl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: brewer2mpl in /usr/local/lib/python3.10/dist-packages (1.4.1)

# %%
from keras.utils.np_utils import to_categorical
import pandas as pd
import numpy as np
import random
import sys
import warnings 
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import brewer2mpl


def emotion_count(y_train, classes):
    """
    The function re-classify picture with disgust label into angry label
    """
    emo_classcount = {}
    print ('Disgust classified as Angry')
    y_train.loc[y_train == 1] = 0
    classes.remove('Disgust')
    for new_num, _class in enumerate(classes):
        y_train.loc[(y_train == emotion[_class])] = new_num
        class_count = sum(y_train == (new_num))
        emo_classcount[_class] = (new_num, class_count)
    return y_train.values, emo_classcount

# def load_data(sample_split=0.3, usage='Training',classes=['Angry','Happy'], filepath='../content/drive/MyDrive/Escuela/ia/reconocer-jetas/fer2013/fer2013.csv'):
def load_data(sample_split=0.3, usage='Training',classes=['Angry','Happy'], filepath='../content/drive/MyDrive/reconocer-jetas/fer2013/fer2013.csv'):
   
    """
    The function load provided CSV dataset and further reshape, rescale the data for feeding
    """
    df = pd.read_csv(filepath)
    df = df[df.Usage == usage]
    frames = []
    classes.append('Disgust')
    for _class in classes:
        class_df = df[df['emotion'] == emotion[_class]]
        frames.append(class_df)
    data = pd.concat(frames, axis=0)
    rows = random.sample(list(data.index), int(len(data)*sample_split))
    data = data.loc[rows]
    x = list(data["pixels"])
    X = []
    for i in range(len(x)):
        each_pixel = [int(num) for num in x[i].split()]
        X.append(each_pixel)
    ## reshape into 48*48*1 and rescale
    X = np.array(X)
    X = X.reshape(X.shape[0], 48, 48,1)
    X = X.astype("float32")
    X /= 255
    
    y_train, new_dict = emotion_count(data.emotion, classes)
    y_train = to_categorical(y_train)
    return X, y_train

# %%
## All three datasets are well loaded accordingly
emotion = {'Angry': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3,
           'Sad': 4, 'Surprise': 5, 'Neutral': 6}
emo     = ['Angry', 'Fear', 'Happy',
           'Sad', 'Surprise', 'Neutral']

X_test, y_test = load_data(sample_split=1.0,classes=emo,
usage='PrivateTest')

X_train, y_train = load_data(sample_split=1.0,classes=emo,
usage= 'Training')

X_val,y_val = load_data(sample_split=1.0,classes=emo,
usage= 'PublicTest')
# Out:
# Disgust classified as Angry
# Disgust classified as Angry
# Disgust classified as Angry

# %%
## The shape of loaded data is under examination
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (28709, 48, 48, 1)
# (28709, 6)
# (3589, 48, 48, 1)
# (3589, 6)
# (3589, 48, 48, 1)
# (3589, 6)

# %%
def save_data(X_test, y_test, fname=''):
    """
    The function stores loaded data into numpy form for further processing
    """
    np.save( 'X_test' + fname, X_test)
    np.save( 'y_test' + fname, y_test)
save_data(X_test, y_test,"_privatetest6_100pct")
X_fname = 'X_test_privatetest6_100pct.npy'
y_fname = 'y_test_privatetest6_100pct.npy'
X = np.load(X_fname)
y = np.load(y_fname)
print ('Private test set')
y_labels = [np.argmax(lst) for lst in y]
counts = np.bincount(y_labels)
labels = ['angry', 'fear', 'happy', 'sad', 'surprise', 'neutral']
print (zip(labels, counts))
# Out:
# Private test set
# <zip object at 0x7f5a049b70c0>

# %%
def overview(start, end, X):
    """
    The function is used to plot first several pictures for overviewing inputs format
    """
    fig = plt.figure(figsize=(48,48))
    for i in range(start, end+1):
        input_img = X[i:(i+1),:,:,:]
        ax = fig.add_subplot(16,12,i+1)
        ax.imshow(input_img[0,:,:,0], cmap=plt.cm.gray)
        plt.xticks(np.array([]))
        plt.yticks(np.array([]))
        plt.tight_layout()
    plt.show()
overview(0,191, X)

# %%
## Similarly we canvisualize any input with self-defined index with following code
input_img = X[6:7,:,:,:] 
print (input_img.shape)
plt.imshow(input_img[0,:,:,0], cmap='gray')
plt.show()
# Out:
# (1, 48, 48, 1)

# %%
y_train = y_train 
y_public = y_val 
y_private = y_test 
y_train_labels  = [np.argmax(lst) for lst in y_train]
y_public_labels = [np.argmax(lst) for lst in y_public]
y_private_labels = [np.argmax(lst) for lst in y_private]

# %%
def plot_distribution(y1, y2, data_names, ylims =[1000,1000]): 
    """
    The function is used to plot the distribution of the labels of provided dataset 
    """
    colorset = brewer2mpl.get_map('Set3', 'qualitative', 6).mpl_colors
    fig = plt.figure(figsize=(8,4))
    ax1 = fig.add_subplot(1,2,1)
    ax1.bar(np.arange(1,7), np.bincount(y1), color=colorset, alpha=0.8)
    ax1.set_xticks(np.arange(1.25,7.25,1))
    ax1.set_xticklabels(labels, rotation=60, fontsize=14)
    ax1.set_xlim([0, 8])
    ax1.set_ylim([0, ylims[0]])
    ax1.set_title(data_names[0])
    
    ax2 = fig.add_subplot(1,2,2)
    ax2.bar(np.arange(1,7), np.bincount(y2), color=colorset, alpha=0.8)
    ax2.set_xticks(np.arange(1.25,7.24,1))
    ax2.set_xticklabels(labels, rotation=60, fontsize=14)
    ax2.set_xlim([0, 8])
    ax2.set_ylim([0, ylims[1]])
    ax2.set_title(data_names[1])
    plt.tight_layout()
    plt.show()
    
plot_distribution(y_train_labels, y_public_labels, \
                  ['Train dataset', 'Public dataset'], \
                  ylims =[8000,1000])

# %%
# Final Model Architecture:
from keras import layers
from keras import models
from keras import optimizers


# model = models.Sequential()
# model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu',input_shape=(48, 48, 1)))
# model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
# model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
# model.add(layers.MaxPooling2D(pool_size=(2, 2)))


# # model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
# # model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
# # model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
# # model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# # model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
# # model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
# # model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
# # model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
# model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
# model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
# model.add(layers.MaxPooling2D(pool_size=(2, 2)))


# model.add(layers.Flatten())  # this converts our 3D feature maps to 1D feature vectors
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Dense(6, activation='softmax'))



# # # optimizer:
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# print ('Training....')

# %%
# from keras import layers
# from keras import models
# from keras import optimizers

# model = models.Sequential()

# model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(48, 48, 1)))
# # model.add(layers.BatchNormalization())  # Add batch normalization after convolutional layers
# model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
# # model.add(layers.BatchNormalization())  # Add batch normalization after convolutional layers
# model.add(layers.MaxPooling2D(pool_size=(2, 2)))
# # model.add(layers.Dropout(0.25))  # Add dropout to reduce overfitting

# model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
# # model.add(layers.BatchNormalization())  # Add batch normalization after convolutional layers
# model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
# # model.add(layers.BatchNormalization())  # Add batch normalization after convolutional layers
# model.add(layers.MaxPooling2D(pool_size=(2, 2)))
# # model.add(layers.Dropout(0.25))  # Add dropout to reduce overfitting

# model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
# # model.add(layers.BatchNormalization())  # Add batch normalization after convolutional layers
# model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
# # model.add(layers.BatchNormalization())  # Add batch normalization after convolutional layers
# model.add(layers.MaxPooling2D(pool_size=(2, 2)))
# # model.add(layers.Dropout(0.25))  # Add dropout to reduce overfitting

# model.add(layers.Flatten())
# model.add(layers.Dense(64, activation='relu'))
# # model.add(layers.Dropout(0.5))  # Add dropout to reduce overfitting
# model.add(layers.Dense(64, activation='relu'))
# # model.add(layers.Dropout(0.5))  # Add dropout to reduce overfitting
# model.add(layers.Dense(6, activation='softmax'))

# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from tensorflow.keras import models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization, Activation

model = models.Sequential()


model.add(Conv2D(64, (3,3), padding='same', input_shape=(48,48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())


model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))


model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))


model.add(Dense(6, activation='softmax'))


model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        640
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_1 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 12, 12, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 12, 12, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  batch_normalization_3 (Batc  (None, 6, 6, 512)        2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 6, 6, 512)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 4,478,214
# Trainable params: 4,474,246
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
#fit
nb_epoch = 250
batch_size = 128

# modelF = modelN.fit(X_train, y_train, nb_epoch=nb_epoch, batch_size=batch_size,
#           validation_data=(X_val, y_val), shuffle=True, verbose=1)
# history = model.fit(X_train, y_train, epochs=nb_epoch, batch_size=batch_size,validation_data=(X_val, y_val), shuffle=True, verbose=1)
# history = model.fit(X_train, y_train, epochs=nb_epoch, batch_size=batch_size,validation_data=(X_val, y_val))
history = model.fit(X_train, y_train, epochs=nb_epoch, batch_size=batch_size,validation_data=(X_test, y_test))
# Out:
# Epoch 1/250
# 225/225 [==============================] - 24s 65ms/step - loss: 1.7224 - accuracy: 0.3231 - val_loss: 2.2122 - val_accuracy: 0.1747
# Epoch 2/250
# 225/225 [==============================] - 14s 62ms/step - loss: 1.3857 - accuracy: 0.4575 - val_loss: 2.0643 - val_accuracy: 0.2772
# Epoch 3/250
# 225/225 [==============================] - 14s 62ms/step - loss: 1.2306 - accuracy: 0.5182 - val_loss: 1.2548 - val_accuracy: 0.5091
# Epoch 4/250
# 225/225 [==============================] - 14s 61ms/step - loss: 1.1377 - accuracy: 0.5594 - val_loss: 1.3031 - val_accuracy: 0.4617
# Epoch 5/250
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0818 - accuracy: 0.5818 - val_loss: 1.3229 - val_accuracy: 0.4678
# Epoch 6/250
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0326 - accuracy: 0.6011 - val_loss: 1.2595 - val_accuracy: 0.5141
# Epoch 7/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.9876 - accuracy: 0.6229 - val_loss: 1.1813 - val_accuracy: 0.5489
# Epoch 8/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.9450 - accuracy: 0.6368 - val_loss: 1.0414 - val_accuracy: 0.6010
# Epoch 9/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.9078 - accuracy: 0.6523 - val_loss: 1.1793 - val_accuracy: 0.5536
# Epoch 10/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.8687 - accuracy: 0.6683 - val_loss: 1.0844 - val_accuracy: 0.5913
# Epoch 11/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.8282 - accuracy: 0.6846 - val_loss: 1.0731 - val_accuracy: 0.5988
# Epoch 12/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.7837 - accuracy: 0.7035 - val_loss: 1.0514 - val_accuracy: 0.6160
# Epoch 13/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.7489 - accuracy: 0.7173 - val_loss: 1.2414 - val_accuracy: 0.5712
# Epoch 14/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.6993 - accuracy: 0.7360 - val_loss: 1.2247 - val_accuracy: 0.5977
# Epoch 15/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.6533 - accuracy: 0.7555 - val_loss: 1.3047 - val_accuracy: 0.5734
# Epoch 16/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.6201 - accuracy: 0.7665 - val_loss: 1.1593 - val_accuracy: 0.6032
# Epoch 17/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.5743 - accuracy: 0.7839 - val_loss: 1.2181 - val_accuracy: 0.6177
# Epoch 18/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.5360 - accuracy: 0.7986 - val_loss: 1.5149 - val_accuracy: 0.5132
# Epoch 19/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.4973 - accuracy: 0.8185 - val_loss: 1.3670 - val_accuracy: 0.5748
# Epoch 20/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.4654 - accuracy: 0.8262 - val_loss: 1.2167 - val_accuracy: 0.6325
# Epoch 21/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.4312 - accuracy: 0.8422 - val_loss: 1.3184 - val_accuracy: 0.5860
# Epoch 22/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.4030 - accuracy: 0.8516 - val_loss: 1.2772 - val_accuracy: 0.6230
# Epoch 23/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.3764 - accuracy: 0.8597 - val_loss: 1.5278 - val_accuracy: 0.5913
# Epoch 24/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.3491 - accuracy: 0.8711 - val_loss: 1.4933 - val_accuracy: 0.5807
# Epoch 25/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.3234 - accuracy: 0.8830 - val_loss: 1.4314 - val_accuracy: 0.5968
# Epoch 26/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.3107 - accuracy: 0.8879 - val_loss: 1.4013 - val_accuracy: 0.6275
# Epoch 27/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.2903 - accuracy: 0.8951 - val_loss: 1.4835 - val_accuracy: 0.6135
# Epoch 28/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.2709 - accuracy: 0.9010 - val_loss: 1.5254 - val_accuracy: 0.6227
# Epoch 29/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.2574 - accuracy: 0.9053 - val_loss: 1.4237 - val_accuracy: 0.6305
# Epoch 30/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.2430 - accuracy: 0.9115 - val_loss: 1.5678 - val_accuracy: 0.6149
# Epoch 31/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.2337 - accuracy: 0.9158 - val_loss: 1.5556 - val_accuracy: 0.6149
# Epoch 32/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.2232 - accuracy: 0.9218 - val_loss: 1.4660 - val_accuracy: 0.6467
# Epoch 33/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.2043 - accuracy: 0.9273 - val_loss: 1.5045 - val_accuracy: 0.6269
# Epoch 34/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.2040 - accuracy: 0.9271 - val_loss: 1.5994 - val_accuracy: 0.6099
# Epoch 35/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1948 - accuracy: 0.9300 - val_loss: 1.6375 - val_accuracy: 0.6294
# Epoch 36/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1917 - accuracy: 0.9316 - val_loss: 1.7193 - val_accuracy: 0.6049
# Epoch 37/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1862 - accuracy: 0.9336 - val_loss: 1.5617 - val_accuracy: 0.6495
# Epoch 38/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1798 - accuracy: 0.9357 - val_loss: 1.5235 - val_accuracy: 0.6461
# Epoch 39/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1700 - accuracy: 0.9396 - val_loss: 1.6820 - val_accuracy: 0.6261
# Epoch 40/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1573 - accuracy: 0.9443 - val_loss: 1.6241 - val_accuracy: 0.6378
# Epoch 41/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1597 - accuracy: 0.9442 - val_loss: 1.6866 - val_accuracy: 0.6447
# Epoch 42/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1569 - accuracy: 0.9452 - val_loss: 1.7148 - val_accuracy: 0.6400
# Epoch 43/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1539 - accuracy: 0.9463 - val_loss: 1.6527 - val_accuracy: 0.6328
# Epoch 44/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1497 - accuracy: 0.9481 - val_loss: 1.6531 - val_accuracy: 0.6289
# Epoch 45/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1496 - accuracy: 0.9482 - val_loss: 1.7341 - val_accuracy: 0.6211
# Epoch 46/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1359 - accuracy: 0.9525 - val_loss: 1.6789 - val_accuracy: 0.6406
# Epoch 47/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1358 - accuracy: 0.9521 - val_loss: 2.1499 - val_accuracy: 0.5417
# Epoch 48/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1383 - accuracy: 0.9522 - val_loss: 1.6700 - val_accuracy: 0.6389
# Epoch 49/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1338 - accuracy: 0.9530 - val_loss: 1.6364 - val_accuracy: 0.6456
# Epoch 50/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1252 - accuracy: 0.9559 - val_loss: 1.6382 - val_accuracy: 0.6576
# Epoch 51/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1275 - accuracy: 0.9556 - val_loss: 1.8367 - val_accuracy: 0.6431
# Epoch 52/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1274 - accuracy: 0.9537 - val_loss: 1.6554 - val_accuracy: 0.6445
# Epoch 53/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1198 - accuracy: 0.9577 - val_loss: 1.7360 - val_accuracy: 0.6308
# Epoch 54/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1166 - accuracy: 0.9585 - val_loss: 1.7361 - val_accuracy: 0.6551
# Epoch 55/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1193 - accuracy: 0.9569 - val_loss: 1.9544 - val_accuracy: 0.6032
# Epoch 56/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1131 - accuracy: 0.9611 - val_loss: 1.7983 - val_accuracy: 0.6436
# Epoch 57/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.1120 - accuracy: 0.9614 - val_loss: 1.8793 - val_accuracy: 0.6314
# Epoch 58/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.1116 - accuracy: 0.9595 - val_loss: 1.7776 - val_accuracy: 0.6439
# Epoch 59/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.1078 - accuracy: 0.9616 - val_loss: 1.8554 - val_accuracy: 0.6378
# Epoch 60/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1070 - accuracy: 0.9629 - val_loss: 1.8813 - val_accuracy: 0.6328
# Epoch 61/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1086 - accuracy: 0.9627 - val_loss: 1.9379 - val_accuracy: 0.6381
# Epoch 62/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1012 - accuracy: 0.9645 - val_loss: 1.7883 - val_accuracy: 0.6617
# Epoch 63/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1006 - accuracy: 0.9653 - val_loss: 1.7951 - val_accuracy: 0.6473
# Epoch 64/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1031 - accuracy: 0.9641 - val_loss: 1.8626 - val_accuracy: 0.6305
# Epoch 65/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0967 - accuracy: 0.9664 - val_loss: 1.9253 - val_accuracy: 0.6152
# Epoch 66/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1061 - accuracy: 0.9634 - val_loss: 1.8186 - val_accuracy: 0.6403
# Epoch 67/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0985 - accuracy: 0.9662 - val_loss: 1.8837 - val_accuracy: 0.6520
# Epoch 68/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0932 - accuracy: 0.9677 - val_loss: 1.9281 - val_accuracy: 0.6478
# Epoch 69/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0936 - accuracy: 0.9666 - val_loss: 1.8321 - val_accuracy: 0.6442
# Epoch 70/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0931 - accuracy: 0.9687 - val_loss: 1.9118 - val_accuracy: 0.6411
# Epoch 71/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0871 - accuracy: 0.9700 - val_loss: 1.7622 - val_accuracy: 0.6492
# Epoch 72/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0957 - accuracy: 0.9669 - val_loss: 2.1487 - val_accuracy: 0.5896
# Epoch 73/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.1000 - accuracy: 0.9643 - val_loss: 1.8317 - val_accuracy: 0.6367
# Epoch 74/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0829 - accuracy: 0.9706 - val_loss: 1.8984 - val_accuracy: 0.6467
# Epoch 75/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0895 - accuracy: 0.9689 - val_loss: 1.9504 - val_accuracy: 0.6459
# Epoch 76/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0872 - accuracy: 0.9701 - val_loss: 1.8877 - val_accuracy: 0.6381
# Epoch 77/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0837 - accuracy: 0.9704 - val_loss: 1.9927 - val_accuracy: 0.6464
# Epoch 78/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0811 - accuracy: 0.9713 - val_loss: 2.1969 - val_accuracy: 0.6057
# Epoch 79/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0846 - accuracy: 0.9709 - val_loss: 2.3073 - val_accuracy: 0.5871
# Epoch 80/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0799 - accuracy: 0.9722 - val_loss: 1.9864 - val_accuracy: 0.6403
# Epoch 81/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0836 - accuracy: 0.9705 - val_loss: 2.1357 - val_accuracy: 0.5971
# Epoch 82/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0868 - accuracy: 0.9691 - val_loss: 1.9711 - val_accuracy: 0.6305
# Epoch 83/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0857 - accuracy: 0.9700 - val_loss: 2.1434 - val_accuracy: 0.6144
# Epoch 84/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0802 - accuracy: 0.9717 - val_loss: 2.0107 - val_accuracy: 0.6272
# Epoch 85/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0763 - accuracy: 0.9747 - val_loss: 1.9543 - val_accuracy: 0.6431
# Epoch 86/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0737 - accuracy: 0.9747 - val_loss: 2.0444 - val_accuracy: 0.6411
# Epoch 87/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0765 - accuracy: 0.9732 - val_loss: 1.9021 - val_accuracy: 0.6470
# Epoch 88/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0804 - accuracy: 0.9713 - val_loss: 1.9441 - val_accuracy: 0.6422
# Epoch 89/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0799 - accuracy: 0.9728 - val_loss: 1.9166 - val_accuracy: 0.6420
# Epoch 90/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0757 - accuracy: 0.9736 - val_loss: 1.9705 - val_accuracy: 0.6576
# Epoch 91/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0748 - accuracy: 0.9739 - val_loss: 2.1053 - val_accuracy: 0.6227
# Epoch 92/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0730 - accuracy: 0.9743 - val_loss: 2.6694 - val_accuracy: 0.5548
# Epoch 93/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0698 - accuracy: 0.9752 - val_loss: 1.9852 - val_accuracy: 0.6590
# Epoch 94/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0695 - accuracy: 0.9759 - val_loss: 1.9995 - val_accuracy: 0.6542
# Epoch 95/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0732 - accuracy: 0.9738 - val_loss: 1.9873 - val_accuracy: 0.6411
# Epoch 96/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0703 - accuracy: 0.9757 - val_loss: 2.0831 - val_accuracy: 0.6152
# Epoch 97/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0756 - accuracy: 0.9726 - val_loss: 1.9793 - val_accuracy: 0.6272
# Epoch 98/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0699 - accuracy: 0.9750 - val_loss: 2.0066 - val_accuracy: 0.6453
# Epoch 99/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0705 - accuracy: 0.9754 - val_loss: 2.0954 - val_accuracy: 0.6392
# Epoch 100/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0673 - accuracy: 0.9758 - val_loss: 2.0068 - val_accuracy: 0.6551
# Epoch 101/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0694 - accuracy: 0.9747 - val_loss: 2.0649 - val_accuracy: 0.6325
# Epoch 102/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0709 - accuracy: 0.9749 - val_loss: 1.9375 - val_accuracy: 0.6500
# Epoch 103/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0670 - accuracy: 0.9760 - val_loss: 2.1373 - val_accuracy: 0.6381
# Epoch 104/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0672 - accuracy: 0.9772 - val_loss: 2.0957 - val_accuracy: 0.6361
# Epoch 105/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0606 - accuracy: 0.9789 - val_loss: 2.1455 - val_accuracy: 0.6367
# Epoch 106/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0708 - accuracy: 0.9751 - val_loss: 2.0788 - val_accuracy: 0.6389
# Epoch 107/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0624 - accuracy: 0.9787 - val_loss: 2.1327 - val_accuracy: 0.6275
# Epoch 108/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0671 - accuracy: 0.9769 - val_loss: 2.3001 - val_accuracy: 0.6066
# Epoch 109/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0619 - accuracy: 0.9776 - val_loss: 1.9315 - val_accuracy: 0.6528
# Epoch 110/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0626 - accuracy: 0.9792 - val_loss: 2.1369 - val_accuracy: 0.6400
# Epoch 111/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0669 - accuracy: 0.9763 - val_loss: 1.9697 - val_accuracy: 0.6592
# Epoch 112/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0600 - accuracy: 0.9791 - val_loss: 2.2085 - val_accuracy: 0.6367
# Epoch 113/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0616 - accuracy: 0.9784 - val_loss: 1.9468 - val_accuracy: 0.6601
# Epoch 114/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0652 - accuracy: 0.9761 - val_loss: 2.2951 - val_accuracy: 0.6317
# Epoch 115/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0584 - accuracy: 0.9788 - val_loss: 2.2247 - val_accuracy: 0.6244
# Epoch 116/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0605 - accuracy: 0.9785 - val_loss: 2.1844 - val_accuracy: 0.6261
# Epoch 117/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0691 - accuracy: 0.9749 - val_loss: 2.0400 - val_accuracy: 0.6473
# Epoch 118/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0575 - accuracy: 0.9805 - val_loss: 2.0726 - val_accuracy: 0.6587
# Epoch 119/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0576 - accuracy: 0.9796 - val_loss: 2.0394 - val_accuracy: 0.6498
# Epoch 120/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0619 - accuracy: 0.9775 - val_loss: 2.1034 - val_accuracy: 0.6509
# Epoch 121/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0633 - accuracy: 0.9777 - val_loss: 2.0562 - val_accuracy: 0.6406
# Epoch 122/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0586 - accuracy: 0.9798 - val_loss: 2.1614 - val_accuracy: 0.6294
# Epoch 123/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0584 - accuracy: 0.9797 - val_loss: 2.0465 - val_accuracy: 0.6520
# Epoch 124/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0571 - accuracy: 0.9805 - val_loss: 1.9854 - val_accuracy: 0.6609
# Epoch 125/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0568 - accuracy: 0.9806 - val_loss: 2.0713 - val_accuracy: 0.6445
# Epoch 126/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0581 - accuracy: 0.9790 - val_loss: 2.0538 - val_accuracy: 0.6445
# Epoch 127/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0557 - accuracy: 0.9805 - val_loss: 2.0612 - val_accuracy: 0.6506
# Epoch 128/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0562 - accuracy: 0.9803 - val_loss: 2.1609 - val_accuracy: 0.6291
# Epoch 129/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0530 - accuracy: 0.9810 - val_loss: 2.0838 - val_accuracy: 0.6445
# Epoch 130/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0539 - accuracy: 0.9821 - val_loss: 2.1001 - val_accuracy: 0.6559
# Epoch 131/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0563 - accuracy: 0.9812 - val_loss: 2.1120 - val_accuracy: 0.6556
# Epoch 132/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0511 - accuracy: 0.9816 - val_loss: 2.1788 - val_accuracy: 0.6406
# Epoch 133/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0538 - accuracy: 0.9806 - val_loss: 2.0715 - val_accuracy: 0.6553
# Epoch 134/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0550 - accuracy: 0.9795 - val_loss: 2.2650 - val_accuracy: 0.6495
# Epoch 135/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0577 - accuracy: 0.9791 - val_loss: 2.1297 - val_accuracy: 0.6467
# Epoch 136/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0509 - accuracy: 0.9822 - val_loss: 2.0659 - val_accuracy: 0.6545
# Epoch 137/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0508 - accuracy: 0.9822 - val_loss: 2.2123 - val_accuracy: 0.6539
# Epoch 138/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0502 - accuracy: 0.9810 - val_loss: 2.1176 - val_accuracy: 0.6604
# Epoch 139/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0513 - accuracy: 0.9814 - val_loss: 2.1701 - val_accuracy: 0.6509
# Epoch 140/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0551 - accuracy: 0.9815 - val_loss: 2.1758 - val_accuracy: 0.6514
# Epoch 141/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0556 - accuracy: 0.9807 - val_loss: 2.0698 - val_accuracy: 0.6548
# Epoch 142/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0494 - accuracy: 0.9822 - val_loss: 2.2496 - val_accuracy: 0.6291
# Epoch 143/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0525 - accuracy: 0.9805 - val_loss: 2.0959 - val_accuracy: 0.6576
# Epoch 144/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0499 - accuracy: 0.9816 - val_loss: 2.0433 - val_accuracy: 0.6512
# Epoch 145/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0511 - accuracy: 0.9825 - val_loss: 2.1607 - val_accuracy: 0.6576
# Epoch 146/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0478 - accuracy: 0.9835 - val_loss: 2.1522 - val_accuracy: 0.6509
# Epoch 147/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0500 - accuracy: 0.9821 - val_loss: 2.1640 - val_accuracy: 0.6531
# Epoch 148/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0566 - accuracy: 0.9811 - val_loss: 2.2111 - val_accuracy: 0.6403
# Epoch 149/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0499 - accuracy: 0.9826 - val_loss: 2.1262 - val_accuracy: 0.6537
# Epoch 150/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0479 - accuracy: 0.9826 - val_loss: 2.1886 - val_accuracy: 0.6417
# Epoch 151/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0481 - accuracy: 0.9830 - val_loss: 2.1479 - val_accuracy: 0.6484
# Epoch 152/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0511 - accuracy: 0.9821 - val_loss: 2.4072 - val_accuracy: 0.6252
# Epoch 153/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0561 - accuracy: 0.9807 - val_loss: 2.1412 - val_accuracy: 0.6375
# Epoch 154/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0500 - accuracy: 0.9816 - val_loss: 2.1328 - val_accuracy: 0.6514
# Epoch 155/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0444 - accuracy: 0.9840 - val_loss: 2.1783 - val_accuracy: 0.6425
# Epoch 156/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0431 - accuracy: 0.9839 - val_loss: 2.2620 - val_accuracy: 0.6514
# Epoch 157/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0504 - accuracy: 0.9822 - val_loss: 2.1980 - val_accuracy: 0.6317
# Epoch 158/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0494 - accuracy: 0.9830 - val_loss: 2.3008 - val_accuracy: 0.6420
# Epoch 159/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0471 - accuracy: 0.9831 - val_loss: 2.2886 - val_accuracy: 0.6344
# Epoch 160/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0455 - accuracy: 0.9834 - val_loss: 2.8339 - val_accuracy: 0.5556
# Epoch 161/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0479 - accuracy: 0.9829 - val_loss: 2.2164 - val_accuracy: 0.6347
# Epoch 162/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0472 - accuracy: 0.9836 - val_loss: 2.1944 - val_accuracy: 0.6319
# Epoch 163/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0434 - accuracy: 0.9849 - val_loss: 2.1420 - val_accuracy: 0.6553
# Epoch 164/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0483 - accuracy: 0.9834 - val_loss: 2.3170 - val_accuracy: 0.6225
# Epoch 165/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0471 - accuracy: 0.9828 - val_loss: 2.1239 - val_accuracy: 0.6514
# Epoch 166/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0472 - accuracy: 0.9827 - val_loss: 2.1740 - val_accuracy: 0.6486
# Epoch 167/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0462 - accuracy: 0.9836 - val_loss: 2.2276 - val_accuracy: 0.6523
# Epoch 168/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0416 - accuracy: 0.9849 - val_loss: 2.1681 - val_accuracy: 0.6428
# Epoch 169/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0471 - accuracy: 0.9841 - val_loss: 2.1377 - val_accuracy: 0.6506
# Epoch 170/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0403 - accuracy: 0.9854 - val_loss: 2.2162 - val_accuracy: 0.6509
# Epoch 171/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0462 - accuracy: 0.9836 - val_loss: 2.2009 - val_accuracy: 0.6358
# Epoch 172/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0432 - accuracy: 0.9852 - val_loss: 2.2020 - val_accuracy: 0.6525
# Epoch 173/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0444 - accuracy: 0.9837 - val_loss: 2.1517 - val_accuracy: 0.6484
# Epoch 174/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0458 - accuracy: 0.9832 - val_loss: 2.1950 - val_accuracy: 0.6556
# Epoch 175/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0422 - accuracy: 0.9845 - val_loss: 2.1966 - val_accuracy: 0.6556
# Epoch 176/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0477 - accuracy: 0.9832 - val_loss: 2.1701 - val_accuracy: 0.6620
# Epoch 177/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0457 - accuracy: 0.9839 - val_loss: 2.2193 - val_accuracy: 0.6372
# Epoch 178/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0412 - accuracy: 0.9853 - val_loss: 2.2913 - val_accuracy: 0.6459
# Epoch 179/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0389 - accuracy: 0.9851 - val_loss: 2.2878 - val_accuracy: 0.6216
# Epoch 180/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0412 - accuracy: 0.9852 - val_loss: 2.3272 - val_accuracy: 0.6473
# Epoch 181/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0425 - accuracy: 0.9852 - val_loss: 2.3279 - val_accuracy: 0.6498
# Epoch 182/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0449 - accuracy: 0.9843 - val_loss: 2.2890 - val_accuracy: 0.6411
# Epoch 183/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0403 - accuracy: 0.9851 - val_loss: 2.4123 - val_accuracy: 0.6381
# Epoch 184/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0401 - accuracy: 0.9851 - val_loss: 2.3004 - val_accuracy: 0.6545
# Epoch 185/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0399 - accuracy: 0.9856 - val_loss: 2.2659 - val_accuracy: 0.6436
# Epoch 186/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0416 - accuracy: 0.9854 - val_loss: 2.2018 - val_accuracy: 0.6539
# Epoch 187/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0393 - accuracy: 0.9855 - val_loss: 2.5383 - val_accuracy: 0.6180
# Epoch 188/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0416 - accuracy: 0.9857 - val_loss: 2.3959 - val_accuracy: 0.6194
# Epoch 189/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0374 - accuracy: 0.9865 - val_loss: 2.4746 - val_accuracy: 0.6358
# Epoch 190/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0405 - accuracy: 0.9853 - val_loss: 2.4086 - val_accuracy: 0.6383
# Epoch 191/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0437 - accuracy: 0.9848 - val_loss: 2.2348 - val_accuracy: 0.6578
# Epoch 192/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0429 - accuracy: 0.9835 - val_loss: 2.2192 - val_accuracy: 0.6539
# Epoch 193/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0401 - accuracy: 0.9856 - val_loss: 2.2967 - val_accuracy: 0.6517
# Epoch 194/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0444 - accuracy: 0.9850 - val_loss: 2.3542 - val_accuracy: 0.6124
# Epoch 195/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0418 - accuracy: 0.9850 - val_loss: 2.1475 - val_accuracy: 0.6587
# Epoch 196/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0394 - accuracy: 0.9866 - val_loss: 2.2263 - val_accuracy: 0.6378
# Epoch 197/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0366 - accuracy: 0.9865 - val_loss: 2.3332 - val_accuracy: 0.6442
# Epoch 198/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0415 - accuracy: 0.9847 - val_loss: 2.2232 - val_accuracy: 0.6570
# Epoch 199/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0365 - accuracy: 0.9864 - val_loss: 2.1593 - val_accuracy: 0.6631
# Epoch 200/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0407 - accuracy: 0.9856 - val_loss: 2.2646 - val_accuracy: 0.6495
# Epoch 201/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0410 - accuracy: 0.9855 - val_loss: 2.3342 - val_accuracy: 0.6411
# Epoch 202/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0394 - accuracy: 0.9859 - val_loss: 2.1345 - val_accuracy: 0.6481
# Epoch 203/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0423 - accuracy: 0.9853 - val_loss: 2.2011 - val_accuracy: 0.6553
# Epoch 204/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0399 - accuracy: 0.9861 - val_loss: 2.2589 - val_accuracy: 0.6330
# Epoch 205/250
# 225/225 [==============================] - 14s 61ms/step - loss: 0.0388 - accuracy: 0.9856 - val_loss: 2.1262 - val_accuracy: 0.6553
# Epoch 206/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0376 - accuracy: 0.9870 - val_loss: 2.2278 - val_accuracy: 0.6514
# Epoch 207/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0363 - accuracy: 0.9876 - val_loss: 2.2018 - val_accuracy: 0.6595
# Epoch 208/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0384 - accuracy: 0.9864 - val_loss: 2.2690 - val_accuracy: 0.6534
# Epoch 209/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0363 - accuracy: 0.9873 - val_loss: 2.3251 - val_accuracy: 0.6503
# Epoch 210/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0372 - accuracy: 0.9873 - val_loss: 2.2531 - val_accuracy: 0.6545
# Epoch 211/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0383 - accuracy: 0.9867 - val_loss: 2.2397 - val_accuracy: 0.6514
# Epoch 212/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0414 - accuracy: 0.9854 - val_loss: 2.2601 - val_accuracy: 0.6514
# Epoch 213/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0366 - accuracy: 0.9869 - val_loss: 2.3123 - val_accuracy: 0.6534
# Epoch 214/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0375 - accuracy: 0.9865 - val_loss: 2.2442 - val_accuracy: 0.6609
# Epoch 215/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0398 - accuracy: 0.9854 - val_loss: 2.3999 - val_accuracy: 0.6199
# Epoch 216/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0336 - accuracy: 0.9878 - val_loss: 2.2613 - val_accuracy: 0.6456
# Epoch 217/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0370 - accuracy: 0.9860 - val_loss: 2.2259 - val_accuracy: 0.6514
# Epoch 218/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0388 - accuracy: 0.9860 - val_loss: 2.3428 - val_accuracy: 0.6364
# Epoch 219/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0350 - accuracy: 0.9876 - val_loss: 2.2648 - val_accuracy: 0.6573
# Epoch 220/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0360 - accuracy: 0.9868 - val_loss: 2.3456 - val_accuracy: 0.6531
# Epoch 221/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0362 - accuracy: 0.9872 - val_loss: 2.3009 - val_accuracy: 0.6542
# Epoch 222/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0357 - accuracy: 0.9870 - val_loss: 2.4217 - val_accuracy: 0.6339
# Epoch 223/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0353 - accuracy: 0.9880 - val_loss: 2.2715 - val_accuracy: 0.6606
# Epoch 224/250
# 225/225 [==============================] - 14s 64ms/step - loss: 0.0346 - accuracy: 0.9875 - val_loss: 2.3204 - val_accuracy: 0.6470
# Epoch 225/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0330 - accuracy: 0.9878 - val_loss: 2.2978 - val_accuracy: 0.6498
# Epoch 226/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0368 - accuracy: 0.9871 - val_loss: 2.2838 - val_accuracy: 0.6523
# Epoch 227/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0343 - accuracy: 0.9879 - val_loss: 2.1848 - val_accuracy: 0.6503
# Epoch 228/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0332 - accuracy: 0.9881 - val_loss: 2.3254 - val_accuracy: 0.6590
# Epoch 229/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0338 - accuracy: 0.9881 - val_loss: 2.3443 - val_accuracy: 0.6500
# Epoch 230/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0373 - accuracy: 0.9873 - val_loss: 2.2611 - val_accuracy: 0.6470
# Epoch 231/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0394 - accuracy: 0.9862 - val_loss: 2.2411 - val_accuracy: 0.6584
# Epoch 232/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0352 - accuracy: 0.9873 - val_loss: 2.2242 - val_accuracy: 0.6512
# Epoch 233/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0404 - accuracy: 0.9859 - val_loss: 2.3169 - val_accuracy: 0.6551
# Epoch 234/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0363 - accuracy: 0.9869 - val_loss: 2.1878 - val_accuracy: 0.6565
# Epoch 235/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0327 - accuracy: 0.9881 - val_loss: 2.3570 - val_accuracy: 0.6587
# Epoch 236/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0352 - accuracy: 0.9875 - val_loss: 2.2909 - val_accuracy: 0.6626
# Epoch 237/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0375 - accuracy: 0.9865 - val_loss: 2.3510 - val_accuracy: 0.6531
# Epoch 238/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0357 - accuracy: 0.9872 - val_loss: 2.2888 - val_accuracy: 0.6601
# Epoch 239/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0358 - accuracy: 0.9865 - val_loss: 2.2705 - val_accuracy: 0.6559
# Epoch 240/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0342 - accuracy: 0.9878 - val_loss: 2.1783 - val_accuracy: 0.6542
# Epoch 241/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0333 - accuracy: 0.9881 - val_loss: 2.2443 - val_accuracy: 0.6528
# Epoch 242/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0370 - accuracy: 0.9873 - val_loss: 2.4834 - val_accuracy: 0.6250
# Epoch 243/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0315 - accuracy: 0.9885 - val_loss: 2.2371 - val_accuracy: 0.6576
# Epoch 244/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0336 - accuracy: 0.9878 - val_loss: 2.5190 - val_accuracy: 0.6250
# Epoch 245/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0287 - accuracy: 0.9897 - val_loss: 2.3695 - val_accuracy: 0.6567
# Epoch 246/250
# 225/225 [==============================] - 14s 62ms/step - loss: 0.0339 - accuracy: 0.9882 - val_loss: 2.3951 - val_accuracy: 0.6578
# Epoch 247/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0311 - accuracy: 0.9890 - val_loss: 2.3541 - val_accuracy: 0.6584
# Epoch 248/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0335 - accuracy: 0.9886 - val_loss: 2.3682 - val_accuracy: 0.6473
# Epoch 249/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0379 - accuracy: 0.9859 - val_loss: 2.3300 - val_accuracy: 0.6389
# Epoch 250/250
# 225/225 [==============================] - 14s 63ms/step - loss: 0.0347 - accuracy: 0.9873 - val_loss: 2.2693 - val_accuracy: 0.6617

# %%
# model.save('facial_1')

# acc = modelF.history['acc']
# val_acc = modelF.history['val_acc']
# loss = modelF.history['loss']
# val_loss = modelF.history['val_loss']

# epochs = range(len(acc))

# plt.plot(epochs, acc, 'bo', label='Training acc')
# plt.plot(epochs, val_acc, 'b', label='Validation acc')
# plt.title('Training and validation accuracy')
# plt.legend()

# plt.figure()

# plt.plot(epochs, loss, 'bo', label='Training loss')
# plt.plot(epochs, val_loss, 'b', label='Validation loss')
# plt.title('Training and validation loss')
# plt.legend()

# plt.show()

from tensorflow.keras.models import load_model

model.save('/content/drive/MyDrive/reconocer-jetas/modelos_propios/mi_modelo_mkar7-250.h5')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'],'r--')
plt.title('Exactitud del modelo')
plt.ylabel('Exactitud')
plt.xlabel('epocas')
plt.legend(['Entrenamiento', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],'r--')
plt.title('Perdidas del modelo')
plt.ylabel('perdidas')
plt.xlabel('epocas')
plt.legend(['Entrenamiento', 'test'], loc='upper left')
plt.show()

# %%
# evaluate model on private test set
score = model.evaluate(X, y, verbose=0)
print ("model %s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# model accuracy: 66.17%

# %%
# prediction and true labels
y_prob = model.predict(X, batch_size=32, verbose=0)
y_pred = [np.argmax(prob) for prob in y_prob]
y_true = [np.argmax(true) for true in y]

# %%
def plot_subjects(start, end, y_pred, y_true, title=False):
    """
    The function is used to plot the picture subjects
    """
    fig = plt.figure(figsize=(12,12))
    emotion = {0:'Angry', 1:'Fear', 2:'Happy', 3:'Sad', 4:'Surprise', 5:'Neutral'}
    for i in range(start, end+1):
        input_img = X[i:(i+1),:,:,:]
        ax = fig.add_subplot(6,6,i+1)
        ax.imshow(input_img[0,:,:,0], cmap=matplotlib.cm.gray)
        plt.xticks(np.array([]))
        plt.yticks(np.array([]))
        if y_pred[i] != y_true[i]:
            plt.xlabel(emotion[y_true[i]], color='#53b3cb',fontsize=12)
        else:
            plt.xlabel(emotion[y_true[i]], fontsize=12)
        if title:
            plt.title(emotion[y_pred[i]], color='blue')
        plt.tight_layout()
    plt.show()

# %%
import brewer2mpl
def plot_probs(start,end, y_prob):
    """
    The function is used to plot the probability in histogram for six labels 
    """
    fig = plt.figure(figsize=(12,12))
    for i in range(start, end+1):
        input_img = X[i:(i+1),:,:,:]
        ax = fig.add_subplot(6,6,i+1)
        set3 = brewer2mpl.get_map('Set3', 'qualitative', 6).mpl_colors
        ax.bar(np.arange(0,6), y_prob[i], color=set3,alpha=0.5)
        ax.set_xticks(np.arange(0.5,6.5,1))
        labels = ['angry', 'fear', 'happy', 'sad', 'surprise','neutral']
        ax.set_xticklabels(labels, rotation=90, fontsize=10)
        ax.set_yticks(np.arange(0.0,1.1,0.5))
        plt.tight_layout()
    plt.show()

# %%
def plot_subjects_with_probs(start, end, y_prob):
    """
    This plotting function is used to plot the probability together with its picture
    """
    iter = int((end - start)/6)
    for i in np.arange(0,iter):
        plot_subjects(i*6,(i+1)*6-1, y_pred, y_true, title=False)
        plot_probs(i*6,(i+1)*6-1, y_prob)

# %%
# plot_subjects_with_probs(0, 36, y_prob)

# %%
def plot_distribution2(y_true, y_pred):
    """
    The function is used to compare the number of true labels as well as prediction results
    """
    colorset = brewer2mpl.get_map('Set3', 'qualitative', 6).mpl_colors
    ind = np.arange(1.5,7,1)  # the x locations for the groups
    width = 0.35   
    fig, ax = plt.subplots()
    true = ax.bar(ind, np.bincount(y_true), width, color=colorset, alpha=1.0)
    pred = ax.bar(ind + width, np.bincount(y_pred), width, color=colorset, alpha=0.3)
    ax.set_xticks(np.arange(1.5,7,1))
    ax.set_xticklabels(labels, rotation=30, fontsize=14)
    ax.set_xlim([1.25, 7.5])
    ax.set_ylim([0, 1000])
    ax.set_title('True and Predicted Label Count (Private)')
    plt.tight_layout()
    plt.show()
    
plot_distribution2(y_true, y_pred)

# %%
# import matplotlib.pyplot as plt
# from sklearn.metrics import confusion_matrix


# def plot_confusion_matrix(y_true, y_pred, cmap=plt.cm.Blues):
#     """
#     The function is used to construct the confusion matrix 
#     """
#     cm = confusion_matrix(y_true, y_pred)
#     fig = plt.figure(figsize=(6,6))
#     matplotlib.rcParams.update({'font.size': 16})
#     ax  = fig.add_subplot(111)
#     matrix = ax.imshow(cm, interpolation='nearest', cmap=cmap)
#     fig.colorbar(matrix) 
#     for i in range(0,6):
#         for j in range(0,6):  
#             ax.text(j,i,cm[i,j],va='center', ha='center')
#     ticks = np.arange(len(labels))
#     ax.set_xticks(ticks)
#     ax.set_xticklabels(labels, rotation=45)
#     ax.set_yticks(ticks)
#     ax.set_yticklabels(labels)
#     plt.tight_layout()
#     plt.ylabel('True label')
#     plt.xlabel('Predicted label')

# plot_confusion_matrix(y_true, y_pred, cmap=plt.cm.YlGnBu)
# plt.show()
